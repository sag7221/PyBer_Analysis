# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
# Read CSV
csv_path = os.path.join("Resources","got.csv")
got_df = pd.read_csv(csv_path)
got_df.head()
got_df.isna().sum()
# Out:
# name                   0
# year                   0
# battle_number          0
# attacker_king          2
# defender_king          3
# attacker_1             0
# attacker_2            28
# attacker_3            35
# attacker_4            36
# defender_1             1
# defender_2            36
# defender_3            38
# defender_4            38
# attacker_outcome       1
# battle_type            1
# major_death            1
# major_capture          1
# attacker_size         14
# defender_size         19
# attacker_commander     1
# defender_commander    10
# summer                 1
# location               1
# region                 0
# note                  33
# dtype: int64

# %%
# Get attacker and defender king data
# Clean up Data
#Find all Nan
got_attacker_series = got_df['attacker_king'].value_counts()
got_attacker_series
# Out:
# Joffrey/Tommen Baratheon    14
# Robb Stark                  10
# Balon/Euron Greyjoy          7
# Stannis Baratheon            5
# Name: attacker_king, dtype: int64

# %%
# Get total battle data
got_defender_series = got_df['defender_king'].value_counts()
got_defender_series
# Out:
# Robb Stark                  14
# Joffrey/Tommen Baratheon    13
# Balon/Euron Greyjoy          4
# Stannis Baratheon            2
# Renly Baratheon              1
# Mance Rayder                 1
# Name: defender_king, dtype: int64

# %%
#Combine the series
total_battles_series = got_attacker_series.add(got_defender_series, fill_value=0)
total_battles_series
# Out:
# Balon/Euron Greyjoy         11.0
# Joffrey/Tommen Baratheon    27.0
# Mance Rayder                 1.0
# Renly Baratheon              1.0
# Robb Stark                  24.0
# Stannis Baratheon            7.0
# dtype: float64

# %%
# Configure plot and ticks
total_battles_series.plot(kind="bar")


# Set textual properties


# Show plot


# Resize plot to display labels
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>
