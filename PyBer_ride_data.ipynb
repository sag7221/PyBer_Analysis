# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
csv_path = os.path.join("PyBer_ride_data.csv")
pyber_df = pd.read_csv(csv_path)
pyber_df
# Out:
#     Month  Avg. Fare ($USD)
# 0     Jan             10.02
# 1     Feb             23.24
# 2     Mar             39.20
# 3   April             35.42
# 4     May             32.34
# 5    June             27.04
# 6    July             43.82
# 7     Aug             10.56
# 8    Sept             11.85
# 9     Oct             27.90
# 10    Nov             20.71
# 11    Dec             20.09

# %%
pyber_df.plot(x="Month",y="Avg. Fare ($USD)")
plt.show()

# %%
# Set x-axis and tick locations.
x_axis = np.arange(len(pyber_df))
tick_locations = [value for value in x_axis]
# Plot the data.
pyber_df.plot(x="Month",y="Avg. Fare ($USD)")
plt.xticks(np.arange(0, 1, step=1))
#plt.xticks(tick_locations, pyber_df['Month'])
plt.show()

# %%
pyber_df.plot(x="Month", y="Avg. Fare ($USD)", kind='bar')
plt.show()
